# %%
import numpy as np
from plotnine import ggplot, geom_point, aes, stat_smooth, facet_wrap
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
from pyambient import generate_noise_arr

# %%
a = generate_noise_arr((800, 800), frequency=0.001, noise_type='perlin', seed=123)

# %%
plt.imshow(a)

# %%
a = generate_noise_arr((800, 800), frequency=0.01, noise_type='open_simplex2', seed=42)
plt.imshow(a);

# %%
a = generate_noise_arr((800, 800), frequency=0.001, noise_type='cellular', seed=123)
plt.imshow(a);
